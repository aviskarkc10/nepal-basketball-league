# %%
import pandas as pd

# %%
df =  pd.read_excel('../data/Nepal Basketball League 2019 Information.xlsx', sheet_name="Player Stat (MEN)")

df
# Out:
#     Nepal Basketball League 2019 (NBL) Player Statistics      Unnamed: 1  \
# 0                                         Organised By               NaN
# 1              Play For Deprived Children Nepal (PDCN)               NaN
# 2    Stats Managed By Official Education Partner of...               NaN
# 3                                                 S.NO       PLAYER NAME
# 4                                                    1      Karma Gurung
# ..                                                 ...               ...
# 125                                                 10    Binesh Neupane
# 126                                                 11      Suman Basnet
# 127                                                 12      Rupak Kunwar
# 128                                                 13       Anish Magar
# 129                                                 14      Asish Basnet
#
#      Unnamed: 2 Unnamed: 3      Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# ...

# %%
player_stats = [df.loc[4:16], df.loc[20:33], df.loc[36:49], df.loc[52:65], df.loc[68:81], df.loc[84:97], df.loc[100:113], df.loc[116:129]]

player_stats = pd.concat(player_stats)

# %%
player_stats.columns
# Out:
# Index(['Nepal Basketball League 2019 (NBL) Player Statistics', 'Unnamed: 1',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31',
#        'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35',
#        'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38'],
#       dtype='object')

# %%
player_stats.head()
# Out:
#   Nepal Basketball League 2019 (NBL) Player Statistics         Unnamed: 1  \
# 4                                                  1         Karma Gurung
# 5                                                  2    Chiranjivi Rokaya
# 6                                                  3          Rajiv Joshi
# 7                                                  4       Binod Shrestha
# 8                                                  5     Kabindra Pradhan
#
#   Unnamed: 2 Unnamed: 3      Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 4          8       GGIC  Shooting Guard       5'11         86         14
# 5         35       GGIC   Small Forward       5'11         66         14
# 6          7       GGIC           Guard       5'10         76         14
# 7          3       GGIC           Gaurd        5'8         78         14
# 8          1       GGIC   Small Forward        6'0         69         14
#
#   Unnamed: 8 Unnamed: 9  ... Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32  \
# ...

# %%
labels = df.iloc[3]
labels_dict = {}
for col in player_stats.columns:
    labels_dict[col] = labels[col]
    
labels_dict
# Out:
# {'Nepal Basketball League 2019 (NBL) Player Statistics': 'S.NO',
#  'Unnamed: 1': 'PLAYER NAME',
#  'Unnamed: 2': 'JERSEY NO.',
#  'Unnamed: 3': 'CLUB',
#  'Unnamed: 4': 'Position',
#  'Unnamed: 5': 'Height',
#  'Unnamed: 6': 'Weight',
#  'Unnamed: 7': 'NO. OF GAME PLAYED',
#  'Unnamed: 8': 'TOTAL SCORE',
#  'Unnamed: 9': 'AVR. SCORE PER GAME',
#  'Unnamed: 10': 'FOULS',
#  'Unnamed: 11': 'TECHNICAL',
#  'Unnamed: 12': 'BLOCK',
#  'Unnamed: 13': 'TOTAL ASSIST',
#  'Unnamed: 14': 'AVR. ASSIST PER GAME',
#  'Unnamed: 15': 'TOTAL REBOUND',
#  'Unnamed: 16': 'AVR. REBOUND PER GAME',
#  'Unnamed: 17': 'STEAL',
#  'Unnamed: 18': 'TOTAL TURN OVER',
#  'Unnamed: 19': 'AVR. TURNOVER PER GAME',
#  'Unnamed: 20': '3 POINTS ATTEMPT',
#  'Unnamed: 21': '3 POINTS MADE',
#  'Unnamed: 22': '3 PA %',
#  'Unnamed: 23': '2 POINT ATTEMPT',
#  'Unnamed: 24': '2 POINT MADE',
#  'Unnamed: 25': '2 PA %',
#  'Unnamed: 26': 'FIELD GOALS ATTEMPT',
#  'Unnamed: 27': 'FIELD GOALS MADE',
# ...

# %%
player_stats.rename(columns={'Unnamed: 1': 'Player', 'Unnamed: 2': 'Jersey No.'})
# Out:
#     Nepal Basketball League 2019 (NBL) Player Statistics             Player  \
# 4                                                    1         Karma Gurung
# 5                                                    2    Chiranjivi Rokaya
# 6                                                    3          Rajiv Joshi
# 7                                                    4       Binod Shrestha
# 8                                                    5     Kabindra Pradhan
# ..                                                 ...                  ...
# 125                                                 10       Binesh Neupane
# 126                                                 11         Suman Basnet
# 127                                                 12         Rupak Kunwar
# 128                                                 13          Anish Magar
# 129                                                 14         Asish Basnet
#
# ...

# %%
player_stats.to_csv('player_stats_men.csv')
